# %% [markdown]
# # New Feature Testing
# Since the presentation, we've been working on making new features from demographics of victims, TRR action responses, and count of officer filed complaints. A full explanation and exploratory analysis of that data can be found in exploratory pt1 in the the notebooks directory
#
# This notebook is to throw new features in logistic, decision tree, random forest models and see if we get better predictions out

# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
import sys
import os
sys.path.insert(0, os.path.abspath("../pipeline"))
import Make_By_Officer_DF as make_officer_df
import Feat_Engineering as feat_engineering_helpers
import Run_Model as run_model
import seaborn as sns
import matplotlib.pyplot as plt

# %%
t1 = (2012, 2014)
t2 = (2015, 2015)
additional_cont_feat, final_df = make_officer_df.make_df(t1, t2)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3254: DtypeWarning: Columns (4,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3331: DtypeWarning: Columns (3,7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3331: DtypeWarning: Columns (0,5,6,7,8,9,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# /Users/lilygrier/git/Police_Misconduct_ML_2020/pipeline/Make_By_Officer_DF.py:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TRR_action_t1_member["force_type"]
# /Users/lilygrier/git/Police_Misconduct_ML_2020/Pipeline/Feat_Engineering.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   complaints["complaints_binned"][complaints["complaints_binned"].isin(bins) == False] = "Other/Unknown"

# %%
display(final_df.isna().sum())
# Out:
# target_use_of_force      0
# target_drug              0
# target_racial            0
# target_sustained         0
# target_nonviolent        0
#                       ...
# current_unit             0
# average_salary         104
# salary_change           45
# race                     0
# gender                   0
# Length: 66, dtype: int64

# %% [markdown]
# ## Test new features with simple logistic model

# %%
cont_feat = ["birth_year", "start_date_timestamp"]
cont_feat.extend(additional_cont_feat)
#cont_feat.remove("trr_firearms_total")
#cont_feat.remove("trr_taser_total")
cat_feat = ["gender", "race", "cleaned_rank"]

# %%
desired_targets = ['target_use_of_force', 'target_drug', 'target_racial',
                   'target_sustained', 'target_nonviolent']
target_col = "any_known_complaint"
feat_engineering_helpers.make_target_col(final_df, desired_targets, target_col)

# %%
log, log_labels =  run_model.single_model(final_df, "LogisticRegression", 
                                          target_col, cont_feat, cat_feat, "balanced_accuracy")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# best  LogisticRegression  metrics:
# {'precision': 0.38461538461538464, 'recall': 0.024630541871921183, 'f1-score': 0.046296296296296294, 'support': 203}
# <sklearn.metrics._plot.precision_recall_curve.PrecisionRecallDisplay object at 0x1a1a6a2ad0>
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 'fixed val threshold metrics: '
#          precision    recall  balanced_accuracy
# Cutoff
# 0.00000   0.141463  1.000000           0.500000
# 0.00001   0.141958  1.000000           0.502029
# 0.01000   0.142456  1.000000           0.504058
# 0.05000   0.144699  0.995074           0.512959
# 0.10000   0.172308  0.827586           0.586277
# 0.20000   0.273109  0.320197           0.589887
# 0.50000   0.384615  0.024631           0.509069
# 0.70000   0.375000  0.014778           0.505360
# 0.90000   0.000000  0.000000           0.500000
# 0.95000   0.000000  0.000000           0.500000

# %%
log_labels
# Out:
# ['any_known_complaint',
#  'birth_year_norm',
#  'start_date_timestamp_norm',
#  'average_salary_norm',
#  'salary_change_norm',
#  'settlement_norm',
#  'trr_total_norm',
#  'Active Resister - Chemical_norm',
#  'Active Resister - Firearm_norm',
#  'Active Resister - Impact Weapon_norm',
#  'Active Resister - Other_norm',
#  'Active Resister - Other Force_norm',
#  'Active Resister - Physical Force - Direct Mechanical_norm',
#  'Active Resister - Physical Force - Holding_norm',
#  'Active Resister - Physical Force - Stunning_norm',
#  'Active Resister - Taser_norm',
#  'Active Resister - Taser Display_norm',
#  'Assailant Assault/Battery - Chemical_norm',
#  'Assailant Assault/Battery - Firearm_norm',
#  'Assailant Assault/Battery - Impact Weapon_norm',
#  'Assailant Assault/Battery - Other_norm',
#  'Assailant Assault/Battery - Other Force_norm',
#  'Assailant Assault/Battery - Physical Force - Direct Mechanical_norm',
#  'Assailant Assault/Battery - Physical Force - Holding_norm',
#  'Assailant Assault/Battery - Physical Force - Stunning_norm',
#  'Assailant Assault/Battery - Taser_norm',
#  'Assailant Deadly Force - Chemical_norm',
#  'Assailant Deadly Force - Firearm_norm',
#  'Assailant Deadly Force - Impact Weapon_norm',
#  'Assailant Deadly Force - Other_norm',
#  'Assailant Deadly Force - Other Force_norm',
#  'Assailant Deadly Force - Physical Force - Direct Mechanical_norm',
#  'Assailant Deadly Force - Physical Force - Holding_norm',
#  'Assailant Deadly Force - Physical Force - Stunning_norm',
#  'Assailant Deadly Force - Taser_norm',
#  'Passive Resister - Chemical_norm',
#  'Passive Resister - Firearm_norm',
#  'Passive Resister - Impact Weapon_norm',
#  'Passive Resister - Other_norm',
#  'Passive Resister - Other Force_norm',
#  'Passive Resister - Physical Force - Holding_norm',
#  'Passive Resister - Physical Force - Stunning_norm',
#  'Passive Resister - Taser_norm',
#  'Non-Violent Civilian Contact_norm',
#  'Officer Drug Use/Possession_norm',
#  'Other/Unknown_norm',
#  'Racial/Ethnic_norm',
#  'Use of Force - No Weapon_norm',
#  'Use of Force - Weapon_norm',
#  'Pcnt Complaints Against ASIAN/PACIFIC ISLANDER_norm',
#  'Pcnt Complaints Against BLACK_norm',
#  'Pcnt Complaints Against HISPANIC_norm',
#  'Pcnt Complaints Against NATIVE AMERICAN/ALASKAN NATIVE_norm',
#  'Pcnt Complaints Against WHITE_norm',
#  'count_sustained_norm',
#  'suspension_length_norm',
#  'x0_FEMALE',
#  'x0_MALE',
#  'x1_ASIAN/PACIFIC ISLANDER',
#  'x1_BLACK',
#  'x1_HISPANIC',
#  'x1_NATIVE AMERICAN/ALASKAN NATIVE',
#  'x1_WHITE',
#  'x2_CAPTAIN',
#  'x2_CHIEF',
#  'x2_COMMANDER',
#  'x2_DEPUTY CHIEF',
#  'x2_DETECTIVE',
#  'x2_FIELD TRAINING OFFICER',
#  'x2_FIRST DEPUTY SUPERINTENDENT',
#  'x2_LIEUTENANT',
#  'x2_POLICE OFFICER',
#  'x2_SERGEANT',
#  'x2_Unknown']

# %%
rf, rf_labels =  run_model.single_model(final_df, "RandomForest", 
                                          target_col, cont_feat, cat_feat, "balanced_accuracy")
# Out:
# best  RandomForest  metrics:
# {'precision': 0.2587991718426501, 'recall': 0.6157635467980296, 'f1-score': 0.36443148688046645, 'support': 203}
# <sklearn.metrics._plot.precision_recall_curve.PrecisionRecallDisplay object at 0x1a1d2c1850>
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 'fixed val threshold metrics: '
#          precision    recall  balanced_accuracy
# Cutoff
# 0.00000   0.141463  1.000000           0.500000
# 0.00001   0.141463  1.000000           0.500000
# 0.01000   0.141463  1.000000           0.500000
# 0.05000   0.141463  1.000000           0.500000
# 0.10000   0.141463  1.000000           0.500000
# 0.20000   0.141463  1.000000           0.500000
# 0.50000   0.258799  0.615764           0.662590
# 0.70000   0.476190  0.049261           0.520166
# 0.90000   0.000000  0.000000           0.500000
# 0.95000   0.000000  0.000000           0.500000

# %%
rf_feature_headers = list(rf_labels)
rf_feature_headers.remove("any_known_complaint")

# %%
rf_features = pd.DataFrame(index = rf_feature_headers, data= rf.feature_importances_)

# %%
pd.set_option('display.max_rows', 73)
rf_features.sort_values(0, ascending=False)
# Out:
#                                                                0
# count_sustained_norm                                1.512755e-01
# Pcnt Complaints Against BLACK_norm                  8.005514e-02
# trr_total_norm                                      7.617635e-02
# start_date_timestamp_norm                           7.480850e-02
# Passive Resister - Other_norm                       7.113888e-02
# birth_year_norm                                     6.159630e-02
# Active Resister - Physical Force - Stunning_norm    6.059862e-02
# Other/Unknown_norm                                  5.714307e-02
# salary_change_norm                                  4.997065e-02
# average_salary_norm                                 4.926085e-02
# Non-Violent Civilian Contact_norm                   3.447023e-02
# Passive Resister - Physical Force - Holding_norm    3.059047e-02
# x0_MALE                                             2.826174e-02
# x0_FEMALE                                           2.772512e-02
# Assailant Assault/Battery - Physical Force - Di...  1.659588e-02
# settlement_norm                                     1.177172e-02
# Pcnt Complaints Against WHITE_norm                  1.096097e-02
# Pcnt Complaints Against HISPANIC_norm               1.031016e-02
# Use of Force - No Weapon_norm                       9.189609e-03
# Active Resister - Taser_norm                        9.148072e-03
# suspension_length_norm                              6.830073e-03
# x2_DETECTIVE                                        6.744321e-03
# x2_SERGEANT                                         6.432177e-03
# x1_BLACK                                            4.098593e-03
# Assailant Assault/Battery - Other Force_norm        4.013976e-03
# Active Resister - Chemical_norm                     4.011385e-03
# Active Resister - Other Force_norm                  3.991077e-03
# Racial/Ethnic_norm                                  3.651254e-03
# Assailant Assault/Battery - Impact Weapon_norm      3.381400e-03
# x1_WHITE                                            3.190214e-03
# Pcnt Complaints Against ASIAN/PACIFIC ISLANDER_...  3.118250e-03
# x2_POLICE OFFICER                                   2.923385e-03
# Passive Resister - Other Force_norm                 2.898020e-03
# Assailant Assault/Battery - Physical Force - St...  2.547580e-03
# Assailant Deadly Force - Firearm_norm               2.490070e-03
# x1_ASIAN/PACIFIC ISLANDER                           2.208238e-03
# x2_FIELD TRAINING OFFICER                           2.146157e-03
# x1_HISPANIC                                         2.108292e-03
# Active Resister - Taser Display_norm                1.957297e-03
# x2_LIEUTENANT                                       1.356781e-03
# Assailant Deadly Force - Other Force_norm           1.189671e-03
# Assailant Assault/Battery - Taser_norm              1.046107e-03
# x1_NATIVE AMERICAN/ALASKAN NATIVE                   8.603445e-04
# x2_CAPTAIN                                          8.433601e-04
# Officer Drug Use/Possession_norm                    7.862486e-04
# Pcnt Complaints Against NATIVE AMERICAN/ALASKAN...  6.484129e-04
# Active Resister - Other_norm                        5.456975e-04
# Assailant Assault/Battery - Physical Force - Ho...  5.400517e-04
# Assailant Assault/Battery - Other_norm              4.806741e-04
# Active Resister - Physical Force - Holding_norm     4.278639e-04
# x2_COMMANDER                                        2.926118e-04
# Active Resister - Physical Force - Direct Mecha...  2.743195e-04
# Assailant Assault/Battery - Chemical_norm           2.237926e-04
# Passive Resister - Impact Weapon_norm               1.716539e-04
# Use of Force - Weapon_norm                          1.221992e-04
# Assailant Deadly Force - Other_norm                 1.097385e-04
# Passive Resister - Chemical_norm                    8.462250e-05
# Passive Resister - Physical Force - Stunning_norm   6.207119e-05
# Assailant Deadly Force - Taser_norm                 3.652613e-05
# Passive Resister - Taser_norm                       3.535135e-05
# x2_DEPUTY CHIEF                                     2.971506e-05
# x2_Unknown                                          2.516577e-05
# Assailant Deadly Force - Physical Force - Stunn...  4.820103e-06
# Active Resister - Impact Weapon_norm                2.542295e-06
# Active Resister - Firearm_norm                      2.437141e-06
# Assailant Assault/Battery - Firearm_norm            2.188301e-06
# x2_FIRST DEPUTY SUPERINTENDENT                      2.080095e-06
# Assailant Deadly Force - Chemical_norm              1.880413e-06
# x2_CHIEF                                            1.218255e-06
# Passive Resister - Firearm_norm                     2.789000e-07
# Assailant Deadly Force - Physical Force - Direc...  0.000000e+00
# Assailant Deadly Force - Physical Force - Holdi...  0.000000e+00
# Assailant Deadly Force - Impact Weapon_norm         0.000000e+00

# %% [markdown]
# This good news! The new features seems to matter, have interpretable results.
# Next steps could probably involve limiting features, but we aren't sure exactly how to go about that
# Visualizations to tell story. Also tell story of how we chose our y
# We should do more with victim demographics, it seems to matter and we've only done one aspect. Next do victim buckets
